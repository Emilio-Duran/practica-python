# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import json

# Cargar los datos
with open('TelecomX_Data.json', 'r') as f:
    datos_crudos = json.load(f)

# Convertir a DataFrame plano (normalizar la estructura anidada)
df = pd.json_normalize(datos_crudos)

# %% [markdown]
# #🔧 Transformación

# %%
df.columns = [col.split('.')[-1] for col in df.columns]

df['Total'] = pd.to_numeric(df['Total'], errors='coerce')

df['Total'] = df['Total'].fillna(0)

df['SeniorCitizen'] = df['SeniorCitizen'].map({1: 'Yes', 0: 'No'})

# %% [markdown]
# #📊 Carga y análisis

# %%
# Verificar la estructura final
print(df.info())

# Mostrar los primeros 5 clientes procesados
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   str
#  1   Churn             7267 non-null   str
#  2   gender            7267 non-null   str
#  3   SeniorCitizen     7267 non-null   str
#  4   Partner           7267 non-null   str
#  5   Dependents        7267 non-null   str
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   str
#  8   MultipleLines     7267 non-null   str
#  9   InternetService   7267 non-null   str
#  10  OnlineSecurity    7267 non-null   str
#  11  OnlineBackup      7267 non-null   str
#  12  DeviceProtection  7267 non-null   str
#  13  TechSupport       7267 non-null   str
#  14  StreamingTV       7267 non-null   str
#  15  StreamingMovies   7267 non-null   str
#  16  Contract          7267 non-null   str
# ...

# %% [markdown]
# #📄Informe final

# %% [markdown]
# 1. La importancia de la estructura
# Aprendimos que los datos suelen guardarse de forma eficiente para las máquinas (en capas o "anidados"), pero que para nosotros son difíciles de interpretar así. Al usar el diccionario, logramos traducir esa estructura técnica en una tabla limpia donde cada columna tiene un nombre y un propósito claro.
#
# 2. La limpieza como paso obligatorio
# No se trata solo de mover los datos, sino de prepararlos. Descubrimos que:
#
# No todo es lo que parece: Había números guardados como texto (como los cargos totales) que nos habrían dado errores en cualquier cálculo si no los transformábamos.
#
# Los "huecos" importan: Aprendimos a identificar valores faltantes (clientes nuevos que aún no generaban cargos) y a darles un tratamiento lógico para no alterar las estadísticas.
#
# 3. El valor predictivo (El "porqué" de todo esto)
# Lo más valioso que aprendimos es que ahora tenemos la capacidad de analizar el abandono de clientes (Churn). Al tener todas las variables unificadas (tipo de contrato, servicios de internet, métodos de pago), podemos ver patrones. Por ejemplo, ahora es fácil cruzar datos para ver si un cliente con soporte técnico es más fiel que uno que no lo tiene.
#
# 4. Flujo de trabajo profesional
# Consolidamos un flujo de trabajo estándar en ciencia de datos: Extraer (conectar con la fuente), Transformar (limpiar y dar formato) y Cargar (dejar listo para el análisis). Esto asegura que cualquier análisis posterior sea confiable y no esté basado en datos erróneos.
#
# En resumen, pasamos de tener un "archivo de sistema" a tener una herramienta estratégica que nos permite entender mejor a los clientes de TelecomX y tomar decisiones para que no se vayan.
